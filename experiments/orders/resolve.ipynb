# %%
# import json
#
# from py_clob_client.client import ClobClient
#
# host = "https://clob.polymarket.com"
# open_client: ClobClient = ClobClient(host=host)

# %%
from app.services.clob_service import ClobService
from app.core.session import get_async_manager
from app.services.market_sync_service import MarketSyncService

# %%
clob_markets = ClobService().get_clob_markets_accepting_orders()
clob_condition_ids = {market['condition_id'] for market in clob_markets}

# %%
clob_condition_ids
# Out:
# {'0xa0c492acb221e77adbe84953fec4fc917e45e8b67121c1852d20e2fb9a29064f',
#  '0x36c8c6a38e89a6c03aefc70fe85b1021a53987edf43533a81054e7e8bd9e6160',
#  '0x0dc593ff34d4cf25f1ae32c6b0a8b2c366706d5d0c540352da2377b183962fb5',
#  '0xe2523ebf261bcd05ae4eccaecaed60706f601e8a73729e850771d01268b46aea',
#  '0xa7a50227ef748231d90652dc4fbe15d1d7fb52121d0b33e9be03a48463682a16',
#  '0x17b9d9abd9064c5d892b522ddb245fdc853183b20dd5001aba4294ebd1c371b8',
#  '0xb75eb39a4d5cdc30280af4792698745c017bdfaa898eba05692bc208121037a6',
#  '0xc68c21f8497c9f4edf6127e6215aa118fd753f8bef0f2f3dda469e6adad43b21',
#  '0x0e5e2ab01564b18347fb7cb3e723b6b6b7e355672abb2acdf6455b0dae4556f8',
#  '0x809ef56628c17a0cf894a33f1692c676fff7ce0c668738b01f2e6ae79300355b',
#  '0x3ad5ad45d7b5e2039c93ab0155293b4d42dfaeacabd97efbcb562f519e18e842',
#  '0x4a8705c6287907c7fcb155a18cd95509f1ef98e6671b577a61a40cc79e0f131b',
#  '0xd20df0cdce4a05e3da9f94850356e8e1029cbac4c3062a8439f5f7ea153f0305',
# ...
